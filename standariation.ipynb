# %%
import numpy as np

# %%
import pandas as pd

# %%
import  matplotlib .pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 261   36           144000          1
# 328   36           118000          1
# 226   36           126000          1
# 353   37            57000          0
# 129   26            84000          0

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
from sklearn .model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.3,random_state=0)

# %%
x_train
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
x_test
# Out:
#      Age  EstimatedSalary
# 132   30            87000
# 309   38            50000
# 341   35            75000
# 196   30            79000
# 246   35            50000
# ..   ...              ...
# 216   49            65000
# 259   45           131000
# 49    31            89000
# 238   46            82000
# 343   47            51000
#
# [120 rows x 2 columns]

# %%
y_train
# Out:
# 92     0
# 223    1
# 234    0
# 232    1
# 377    0
#       ..
# 323    1
# 192    0
# 117    0
# 47     0
# 172    0
# Name: Purchased, Length: 280, dtype: int64

# %%
y_test
# Out:
# 132    0
# 309    0
# 341    0
# 196    0
# 246    0
#       ..
# 216    0
# 259    1
# 49     0
# 238    0
# 343    1
# Name: Purchased, Length: 120, dtype: int64

# %%
x_train.shape
# Out:
# (280, 2)

# %%
x_test.shape
# Out:
# (120, 2)

# %%
y_train.shape
# Out:
# (280,)

# %%
y_test.shape
# Out:
# (120,)

# %% [markdown]
# # standarad salar

# %%
from sklearn .preprocessing import StandardScaler

# %%
Scaler =  StandardScaler()

# %%
Scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
Scaler.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# # formula apply

# %%
x_train_s= Scaler.transform(x_train)
x_test_s= Scaler.transform(x_test)

# %%
x_train_s
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %%
x_train_st = pd.DataFrame(x_train_s,columns=x_train.columns)
x_test_st = pd.DataFrame(x_test_s,columns=x_test.columns)

# %%
x_train_st
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %%
x_test_st
# Out:
#           Age  EstimatedSalary
# 0   -0.771013         0.497201
# 1    0.013305        -0.572804
# 2   -0.280814         0.150172
# 3   -0.771013         0.265849
# 4   -0.280814        -0.572804
# ..        ...              ...
# 115  1.091743        -0.139018
# 116  0.699584         1.769639
# 117 -0.672973         0.555039
# 118  0.797624         0.352606
# 119  0.895664        -0.543885
#
# [120 rows x 2 columns]

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(x_train_st.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# # effet of saling

# %%
fig, (a1,a2) = plt.subplots(ncols=2, figsize=(12,5))
a1.scatter(x_train['Age'],x_train['EstimatedSalary'])
a1.set_title('before')
a2.scatter(x_train_st['Age'],x_train_st['EstimatedSalary'])
a2.set_title('after')
# Out:
# Text(0.5, 1.0, 'after')

# %%
fig, (a1,a2) = plt.subplots(ncols=2, figsize=(12,5))
sns.kdeplot(x_train['Age'],ax=a1)
sns.kdeplot(x_train['EstimatedSalary'],ax=a1)

sns.kdeplot(x_train_st['Age'],ax=a2)
sns.kdeplot(x_train_st['EstimatedSalary'],ax=a2)
a2.set_title('after')
# Out:
# Text(0.5, 1.0, 'after')
